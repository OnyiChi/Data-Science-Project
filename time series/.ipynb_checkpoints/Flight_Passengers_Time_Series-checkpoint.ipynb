# %% [markdown]
# # Importing Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Dataset
#
# Using Seaborn to load the 'flights' dataset and display its first few rows:

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
data = sns.load_dataset('flights')
data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# This dataset contains monthly totals of international airline passengers from 1949 to 1960.

# %% [markdown]
# ## Creating a Date Index
#
#  creating a 'date' column and set it as the DataFrame index:

# %%
data['date'] = pd.to_datetime('01-'+data['month'].astype(str)+'-'+data['year'].astype(str))

data.set_index('date', inplace = True)

# %%
data.head()
# Out:
#             year month  passengers
# date
# 1949-01-01  1949   Jan         112
# 1949-02-01  1949   Feb         118
# 1949-03-01  1949   Mar         132
# 1949-04-01  1949   Apr         129
# 1949-05-01  1949   May         121

# %% [markdown]
# ## Data Overview

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 1949-01-01 to 1960-12-01
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 3.9 KB

# %% [markdown]
# ## Plotting the Time Series
#
# plotting the number of passengers over time:

# %%
sns.lineplot(data = data, x=data.index, y= data.passengers)
# Out:
# <Axes: xlabel='date', ylabel='passengers'>

# %% [markdown]
# ## Checking stationarity
#
#
# ### Rolling Statistics
#
# calculating the rolling mean and standard deviation:

# %%
#rolling the average by 12 months

data['rollmean'] = data.passengers.rolling(window=12).mean()
data['rollstd'] = data.passengers.rolling(window=12).std()

# %%
sns.lineplot(data=data, x=data.index, y= data.passengers, label = 'Passengers')
sns.lineplot(data=data, x=data.index, y= data.rollmean, label = 'Rolling Mean')
sns.lineplot(data=data, x=data.index, y= data.rollstd, label = 'Rolling Std.')
plt.legend()

# %% [markdown]
# The plot shows that the mean is not constant, indicating non-stationarity.

# %% [markdown]
# ### Augmented Dickey-Fuller Test
#
# performing the Augmented Dickey-Fuller test to statistically test stationarity:

# %%
from statsmodels.tsa.stattools import adfuller

# %%
AdfTest = adfuller(data['passengers'], autolag = 'AIC')

# %%
AdfTest
# Out:
# (0.8153688792060597,
#  0.9918802434376411,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  996.692930839019)

# %%
# Create a pandas Series from the test results
stats = pd.Series(AdfTest[0:4], index=['Test Statistic', 'p-value', '#lags used', 'number of observations used'])

# Display the Series
print(stats)
# Out:
# Test Statistic                   0.815369
# p-value                          0.991880
# #lags used                      13.000000
# number of observations used    130.000000
# dtype: float64

# %%
for key, values in AdfTest[4].items():
    print('criticality',key,":",values)
# Out:
# criticality 1% : -3.4816817173418295
# criticality 5% : -2.8840418343195267
# criticality 10% : -2.578770059171598

# %% [markdown]
# Critical values < test statistics, therefore data is NOT stationary

# %% [markdown]
# ## Handling Stationarity
#
#
# ### Creating a Test Function
#
# Defining a function to perform stationarity tests:

# %%
def test_stationarity(dataFrame, var):
    dataFrame['rollmean']  = dataFrame[var].rolling(window=12).mean()
    dataFrame['rollstd']  = dataFrame[var].rolling(window=12).std()
    
    from statsmodels.tsa.stattools import adfuller
    AdfTest = adfuller(dataFrame[var],autolag='AIC')
    stats = pd.Series(AdfTest[0:4], index=['Test Statistic', 'p-value', '#lags used', 'number of observations used'])
    print(stats)
    
    for key, values in AdfTest[4].items():
        print('criticality',key,":",values)
        
    sns.lineplot(data=dataFrame,x=dataFrame.index,y=var)
    sns.lineplot(data=data, x=data.index, y= data.rollmean, label = 'Rolling Mean')
    sns.lineplot(data=data, x=data.index, y= data.rollstd, label = 'Rolling Std.')
    plt.legend()

# %%
data.head()
# Out:
#             year month  passengers  rollmean  rollstd
# date
# 1949-01-01  1949   Jan         112       NaN      NaN
# 1949-02-01  1949   Feb         118       NaN      NaN
# 1949-03-01  1949   Mar         132       NaN      NaN
# 1949-04-01  1949   Apr         129       NaN      NaN
# 1949-05-01  1949   May         121       NaN      NaN

# %%
air_data = data[['passengers']]
air_data.head()
# Out:
#             passengers
# date
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# ## Transformation Methods
#
#
# ### Method 1: Time Shift
#
#
# Using time shifting to transform the data:

# %%
import warnings

# Ignore warnings
warnings.filterwarnings("ignore")

air_data['shift'] = air_data.passengers.shift() #shifting by 1 month
air_data['shiftDiff'] = air_data['passengers'] - air_data['shift'] # finding the difference
air_data.head()
# Out:
#             passengers  shift  shiftDiff
# date
# 1949-01-01         112    NaN        NaN
# 1949-02-01         118  112.0        6.0
# 1949-03-01         132  118.0       14.0
# 1949-04-01         129  132.0       -3.0
# 1949-05-01         121  129.0       -8.0

# %%
test_stationarity(air_data.dropna(),'shiftDiff')
# Out:
# Test Statistic                  -2.829267
# p-value                          0.054213
# #lags used                      12.000000
# number of observations used    130.000000
# dtype: float64
# criticality 1% : -3.4816817173418295
# criticality 5% : -2.8840418343195267
# criticality 10% : -2.578770059171598

# %% [markdown]
# ### Method 2 : Log Transformation

# %%
log_data = data[['passengers']]
log_data['log'] = np.log(log_data['passengers'])
log_data.head()
# Out:
#             passengers       log
# date
# 1949-01-01         112  4.718499
# 1949-02-01         118  4.770685
# 1949-03-01         132  4.882802
# 1949-04-01         129  4.859812
# 1949-05-01         121  4.795791

# %%
test_stationarity(log_data,'log')
# Out:
# Test Statistic                  -1.717017
# p-value                          0.422367
# #lags used                      13.000000
# number of observations used    130.000000
# dtype: float64
# criticality 1% : -3.4816817173418295
# criticality 5% : -2.8840418343195267
# criticality 10% : -2.578770059171598

# %% [markdown]
# ## Square Root and Cube Root Transformation
#
#
# applying square root and cube root transformations:

# %%
sqrt_data = data[['passengers']]
sqrt_data['sqrt'] = np.sqrt(data['passengers'])
sqrt_data.head()
# Out:
#             passengers       sqrt
# date
# 1949-01-01         112  10.583005
# 1949-02-01         118  10.862780
# 1949-03-01         132  11.489125
# 1949-04-01         129  11.357817
# 1949-05-01         121  11.000000

# %%
test_stationarity(sqrt_data,'sqrt')
# Out:
# Test Statistic                  -0.345854
# p-value                          0.918754
# #lags used                      13.000000
# number of observations used    130.000000
# dtype: float64
# criticality 1% : -3.4816817173418295
# criticality 5% : -2.8840418343195267
# criticality 10% : -2.578770059171598

# %%
cbrt_data = data[['passengers']]
cbrt_data['cbrt'] = np.cbrt(cbrt_data['passengers'])
cbrt_data.head()
# Out:
#             passengers      cbrt
# date
# 1949-01-01         112  4.820285
# 1949-02-01         118  4.904868
# 1949-03-01         132  5.091643
# 1949-04-01         129  5.052774
# 1949-05-01         121  4.946087

# %%
test_stationarity(cbrt_data,'cbrt')
# Out:
# Test Statistic                  -0.810035
# p-value                          0.816157
# #lags used                      13.000000
# number of observations used    130.000000
# dtype: float64
# criticality 1% : -3.4816817173418295
# criticality 5% : -2.8840418343195267
# criticality 10% : -2.578770059171598

# %% [markdown]
# ## Log and Square Root Combination
#
# Combining log and square root transformations:

# %%
log_data2 = log_data[['passengers','log']]
log_data2['log_sqrt'] = np.sqrt(log_data['log'])
log_data2['logShiftDiff'] = log_data2['log_sqrt'] - log_data2['log_sqrt'].shift()
log_data2.head()
# Out:
#             passengers       log  log_sqrt  logShiftDiff
# date
# 1949-01-01         112  4.718499  2.172211           NaN
# 1949-02-01         118  4.770685  2.184190      0.011979
# 1949-03-01         132  4.882802  2.209706      0.025517
# 1949-04-01         129  4.859812  2.204498     -0.005208
# 1949-05-01         121  4.795791  2.189929     -0.014569

# %%
test_stationarity(log_data2.dropna(),'logShiftDiff')
# Out:
# Test Statistic                  -2.611019
# p-value                          0.090741
# #lags used                      14.000000
# number of observations used    128.000000
# dtype: float64
# criticality 1% : -3.4825006939887997
# criticality 5% : -2.884397984161377
# criticality 10% : -2.578960197753906

# %% [markdown]
# ## Differencing
#
#
# creating differenced series to handle stationarity:

# %%
log_shift = data[['passengers']].copy(deep=True)
log_shift['log'] = np.log(log_shift['passengers'])
log_shift['logShift'] = log_shift['log'].shift()
log_shift['logShiftDiff'] = log_shift['log'] - log_shift['logShift']
log_shift.head()
# Out:
#             passengers       log  logShift  logShiftDiff
# date
# 1949-01-01         112  4.718499       NaN           NaN
# 1949-02-01         118  4.770685  4.718499      0.052186
# 1949-03-01         132  4.882802  4.770685      0.112117
# 1949-04-01         129  4.859812  4.882802     -0.022990
# 1949-05-01         121  4.795791  4.859812     -0.064022

# %%
test_stationarity(log_shift.dropna(),'logShiftDiff')
# Out:
# Test Statistic                  -2.717131
# p-value                          0.071121
# #lags used                      14.000000
# number of observations used    128.000000
# dtype: float64
# criticality 1% : -3.4825006939887997
# criticality 5% : -2.884397984161377
# criticality 10% : -2.578960197753906

# %%
airP = data[['passengers']].copy(deep=True)
airP['firstDiff'] = airP['passengers'].diff()
airP['Diff12'] = airP['passengers'].diff(12)

# %%
airP.head()
# Out:
#             passengers  firstDiff  Diff12
# date
# 1949-01-01         112        NaN     NaN
# 1949-02-01         118        6.0     NaN
# 1949-03-01         132       14.0     NaN
# 1949-04-01         129       -3.0     NaN
# 1949-05-01         121       -8.0     NaN

# %% [markdown]
# ## ARIMA Model
#
#
# fitting an ARIMA model to the data:

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_pacf(airP['firstDiff'].dropna(),lags=20);

# %%
plot_acf(airP['firstDiff'].dropna(),lags=20);

# %%
#splitting dataset into test and train data
train = airP[:round(len(airP)*70/100)]
test = airP[round(len(airP)*70/100):]
test.head()
# Out:
#             passengers  firstDiff  Diff12
# date
# 1957-06-01         422       67.0    48.0
# 1957-07-01         465       43.0    52.0
# 1957-08-01         467        2.0    62.0
# 1957-09-01         404      -63.0    49.0
# 1957-10-01         347      -57.0    41.0

# %%
model = ARIMA(train['passengers'],order=(1,1,3))
model_fit = model.fit()
prediction = model_fit.predict(start=test.index[0],end=test.index[-1])
airP['arimaPred'] = prediction
airP.tail()
# Out:
#             passengers  firstDiff  Diff12   arimaPred
# date
# 1960-08-01         606      -16.0    47.0  341.111333
# 1960-09-01         508      -98.0    45.0  341.111333
# 1960-10-01         461      -47.0    54.0  341.111333
# 1960-11-01         390      -71.0    28.0  341.111333
# 1960-12-01         432       42.0    27.0  341.111333

# %%
airP.dropna()
sns.lineplot(data=airP,x=airP.index,y='passengers')
sns.lineplot(data=airP,x=airP.index,y='arimaPred')
# Out:
# <Axes: xlabel='date', ylabel='passengers'>

# %% [markdown]
# ### Evaluating ARIMA Model
#
#
#  calculating the root mean square error (RMSE):

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(test['passengers'],prediction))
# Out:
# 111.11010337460807

# %% [markdown]
# ### Seasonal Arima Model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
plot_pacf(airP['Diff12'].dropna(),lags=20);
plot_acf(airP['Diff12'].dropna(),lags=20);

# %%
model = SARIMAX(train['passengers'],order=(1,1,3),seasonal_order=(2,1,2,12))
model_fit = model.fit()
prediction = model_fit.predict(start=test.index[0],end=test.index[-1])
airP['sarimaxPred'] = prediction

# %%
airP.dropna()
sns.lineplot(data=airP,x=airP.index,y='passengers')
sns.lineplot(data=airP,x=airP.index,y='sarimaxPred')
sns.lineplot(data=airP,x=airP.index,y='arimaPred')
# model_fit.predict(start=futureDate.index[0],end=futureDate.index[-1]).plot(color='black')
# Out:
# <Axes: xlabel='date', ylabel='passengers'>

# %%
np.sqrt(mean_squared_error(test['passengers'],prediction))
# Out:
# 27.502759589302123

# %% [markdown]
# ## Future Forecasting
#
# Forecasting future values using the SARIMAX model:

# %%
futureDate = pd.DataFrame(pd.date_range(start='1961-01-01', end='1962-12-01',freq='MS'),columns=['Dates'])
futureDate.set_index('Dates',inplace=True)
futureDate.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [1961-01-01 00:00:00, 1961-02-01 00:00:00, 1961-03-01 00:00:00, 1961-04-01 00:00:00, 1961-05-01 00:00:00]

# %%
model_fit.predict(start=futureDate.index[0],end=futureDate.index[-1])
# Out:
# 1961-01-01    490.671147
# 1961-02-01    465.162021
# 1961-03-01    532.968212
# 1961-04-01    530.211805
# 1961-05-01    542.086517
# 1961-06-01    612.662775
# 1961-07-01    674.640712
# 1961-08-01    657.217272
# 1961-09-01    588.194526
# 1961-10-01    528.952410
# 1961-11-01    478.641883
# 1961-12-01    526.708936
# 1962-01-01    541.609422
# 1962-02-01    513.238365
# 1962-03-01    585.356606
# 1962-04-01    583.031254
# 1962-05-01    596.055795
# 1962-06-01    671.998117
# 1962-07-01    738.087358
# 1962-08-01    718.535987
# 1962-09-01    645.022317
# 1962-10-01    581.847900
# 1962-11-01    528.687355
# 1962-12-01    579.357470
# Freq: MS, Name: predicted_mean, dtype: float64

# %% [markdown]
# ## Visualizing Predictions
#
# plotting the actual and predicted values:

# %%
airP.dropna()
sns.lineplot(data=airP,x=airP.index,y='passengers')
sns.lineplot(data=airP,x=airP.index,y='sarimaxPred')
sns.lineplot(data=airP,x=airP.index,y='arimaPred')
model_fit.predict(start=futureDate.index[0],end=futureDate.index[-1]).plot(color='black')
# Out:
# <Axes: xlabel='date', ylabel='passengers'>

# %% [markdown]
# This visualization helps in comparing the model predictions with actual values.

# %%
checkDf = data[['passengers']]
checkDf['diff1'] = checkDf.diff()
# checkDf['diffInv'] = checkDf['diff1'].diffinv()
checkDf.head()
# Out:
#             passengers  diff1
# date
# 1949-01-01         112    NaN
# 1949-02-01         118    6.0
# 1949-03-01         132   14.0
# 1949-04-01         129   -3.0
# 1949-05-01         121   -8.0
